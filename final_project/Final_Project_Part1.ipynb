# %% [markdown]
# `Auteur: Amadou LY`

# %% [markdown]
# # Projet Final M2SID

# %% [markdown]
# ## Objectif

# %% [markdown]
# ## Analyse Exploratoire.

# %%
import numpy as np

# pour rendre les outputs de ce notebook identiques à chaque exécution
np.random.seed(28)

# ignorer les FuturWarnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import os
from wine_aly import helpers

CSV_PATH = os.path.join("../", "datasets", "winequality-red.csv")


winred = helpers.load_csv(CSV_PATH,sep=";")
winred.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
CSV_PATH = os.path.join("../", "datasets","winequality-white.csv")


winwhite = helpers.load_csv(CSV_PATH,sep=";")
winwhite.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Wine-Red

# %%
#creer de copie 
dfr=winred.copy()
dfr.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# ## Analyse Exploratoire

# %% [markdown]
# ### Analyse de forme

# %% [markdown]
# #### Dimension

# %%
dfr.shape
# Out:
# (1599, 12)

# %% [markdown]
# sa renvois nombre de variable et nombre total des enregistrements

# %%
dfr.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# donne les types de variables

# %%
dfr.dtypes.value_counts()
# Out:
# float64    11
# int64       1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (20,10))
sns.heatmap(dfr.isna())
# Out:
# <AxesSubplot:>

# %%
(dfr.isna().sum()/dfr.shape[0]).sort_values(ascending = False)
# Out:
# quality                 0.0
# alcohol                 0.0
# sulphates               0.0
# pH                      0.0
# density                 0.0
# total sulfur dioxide    0.0
# free sulfur dioxide     0.0
# chlorides               0.0
# residual sugar          0.0
# citric acid             0.0
# volatile acidity        0.0
# fixed acidity           0.0
# dtype: float64

# %% [markdown]
# ###### yep! pas de valeurs manquantes

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ###### sa retourne les information detaillee sur les variables

# %%
dfr.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ###### sa sort  nombre total de enregistrements , moyenne,min et max de chaque variable

# %%
dfr.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ###### s'affiche la correlation entre toutes les variables

# %% [markdown]
# ###  Correlation Matrix

# %%
corr = dfr.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### visualisation de correlation entre toutes les variables

# %% [markdown]
# * la correlation entre les variables qui depasse 50 percent  :
#     * fixed acicdity  et citric acid = 0.67
#     * fixed acidity  et density = 0.67
#     * fixed acidity et pH= -0.68
#     * acid citric et pH= -0.54
#     * acid citric et volatile = -0.55
#     * alcohol et density = -0.5

# %% [markdown]
# ## Visualisation

# %%
sns.violinplot(y = "fixed acidity", data = dfr)
# Out:
# <AxesSubplot:ylabel='fixed acidity'>

# %% [markdown]
# * fixed acidity (acidité fixer): la plupart des acides impliqués dans la vin ou fixes ou non volatile (ne s'evaporent pas facilement ) on a :
#
#     * max = 15.9
#     * min= 4.6
#     * moyenne = 8.319637
# * sa nous montre la distribution de variable fixed acidity la partie vaste c'est la ou probabilite élevé
#   partie inferieur et superieur la ou probabilité est faible

# %%
sns.violinplot(y = "volatile acidity", data = dfr)
# Out:
# <AxesSubplot:ylabel='volatile acidity'>

# %% [markdown]
# * volatile acidity(acidité volatile): la quantité d'acide acetique dans la vin qui a des niveaux trop elevé peut conduire a un gout de vinaigre desagreable
#
#     * max = 1.58
#     * min = 0.12
#     * moyenne = 0.527821
#
# * On a ici la distribution du variable volatile acidity

# %%
sns.violinplot(y = "citric acid", data = dfr)
# Out:
# <AxesSubplot:ylabel='citric acid'>

# %% [markdown]
# * citric acid(acide citrique): trouvé en petites quantités ,l'acide citrique pet ajouter de la "fraicheur" et de la saveur aux vins
#
#     * min = 0
#     * max  = 1
#     * moyenne = 0.270976
#
# * Distribution du variables citric acid

# %%
sns.violinplot(y = "residual sugar", data = dfr)
# Out:
# <AxesSubplot:ylabel='residual sugar'>

# %% [markdown]
# * residual sugar(sucre résiduel): la quantité de sucre restant apres l'arret de la fermentation ,il est rare de trouver des vins avec 1g/L et les vins avec plus de 45g/L sont considere comme doux.
#
#     * min = 0.9
#     * max =  15.5
#     * moyenne = 2.538806
#
# * Distribution du variable residual sugar

# %%
sns.violinplot(y = "chlorides", data = dfr)
# Out:
# <AxesSubplot:ylabel='chlorides'>

# %% [markdown]
# * chlorides(chlorures):la quantité de sel dans le vin
#
#     * max = 0.611000
#     * min = 0.012
#     * moyenne = 0.087467
#
# * Distribution du variable chlorides

# %%
sns.violinplot(y = "free sulfur dioxide", data = dfr)
# Out:
# <AxesSubplot:ylabel='free sulfur dioxide'>

# %% [markdown]
# * free sulfur dioxide (dioxyde de soufre libre):la forme libre de SO2 existe enequilibre entre le SO2 moleculaire (sous forme de gaz dissous) et l'ion bisulfate ; il empeche la croissance microbienne et l'oxydation du vin .
#
#     * max = 72
#     * min =1
#     * moyenne = 15.874922
#
# * Distribution du variable free sulfur dioxide

# %%
sns.violinplot(y = "total sulfur dioxide", data = dfr)
# Out:
# <AxesSubplot:ylabel='total sulfur dioxide'>

# %% [markdown]
# * total sulfur dioxide (dioxyde de soufre total):quantité de formes libres et liées de S02; à de faibles concentrations, le SO2 est principalement indétectable dans le vin, mais à des concentrations de SO2 libre supérieures à 50 ppm, le SO2 devient évident dans le nez et le goût du vin la zone du dispersion du variable en plus on a.
#     * max = 289
#     * min =6
#     * moyenne = 46.467792
#
# * Distribution du variable total sulfur dioxide

# %%
sns.violinplot(y = "density", data = dfr)
# Out:
# <AxesSubplot:ylabel='density'>

# %% [markdown]
# * density (g/cm3)la densité de l'eau est proche de celle de l'eau en fonction du pourcentage d'alcool et de sucre
#
#     * max = 1.003690
#     * min =0.990070
#     * moyenne = 0.996747
#
# * Distribution du variable density

# %%
sns.violinplot(y = "pH", data = dfr)
# Out:
# <AxesSubplot:ylabel='pH'>

# %% [markdown]
# * pH décrit dans quelle mesure un vin est acide ou basique sur une échelle de 0 (très acide) à 14 (très basique);
#     la plupart des vins sont entre 3-4 sur l'échelle de pH
#
#     * max = 4.010
#     * min =2.74
#     * moyenne = 3.311113
#
# * Distribution du variable pH

# %%
sns.violinplot(y = "sulphates", data = dfr)
# Out:
# <AxesSubplot:ylabel='sulphates'>

# %% [markdown]
# * sulphates un additif pour le vin qui peut contribuer aux niveaux de gaz sulfureux (S02), qui agit comme un antimicrobien et un       antioxydant
#
#     * max = 2
#     * min =0.33
#     * moyenne =0.658
#
# * Distribution du variable sulphates

# %%
sns.violinplot(y = "alcohol", data = dfr)
# Out:
# <AxesSubplot:ylabel='alcohol'>

# %% [markdown]
# * alcohol le pourcentage d'alcool du vin
#
#     * max = 14.9
#     * min = 8.40
#     * moyenne =10.422
#
# * Distribution de variable alcohol

# %%
sns.violinplot(y = "quality", data = dfr)
# Out:
# <AxesSubplot:ylabel='quality'>

# %% [markdown]
# * quality qualité (score entre 0 et 10)
#      * max = 8
#      * min = 3
#      * moyenne = 5.636023
#
#   Distribution du variable quality

# %% [markdown]
# ###### Avec 'violinplot' on visualise les densites de chaque variables et on remarque les distribution de chaque variables

# %%
for colonne in dfr.select_dtypes('float'):
    plt.figure(figsize = (10,8))
    sns.distplot(dfr[colonne])
    plt.show()

# %% [markdown]
# ###### Avec displot on peut visualiser les variables en fonction de leurs densites on remarque que les variables on presque une distribution normal

# %%
plt.figure(figsize = (10,8))
sns.distplot(dfr['quality'])
plt.show()

# %% [markdown]
# ###### Variable quality en fonction de sa densite

# %% [markdown]
# ### wine-white

# %%
dfw=winwhite.copy()
dfw.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %% [markdown]
# ## Analyse de forme

# %% [markdown]
# #### Dimension

# %%
dfw.shape
# Out:
# (4898, 12)

# %%
dfw.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# Types de variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (20,10))
sns.heatmap(dfw.isna())
# Out:
# <AxesSubplot:>

# %%
(dfw.isna().sum()/dfw.shape[0]).sort_values(ascending = False)
# Out:
# quality                 0.0
# alcohol                 0.0
# sulphates               0.0
# pH                      0.0
# density                 0.0
# total sulfur dioxide    0.0
# free sulfur dioxide     0.0
# chlorides               0.0
# residual sugar          0.0
# citric acid             0.0
# volatile acidity        0.0
# fixed acidity           0.0
# dtype: float64

# %% [markdown]
# ###### Yep! encore pas de valeurs manquantes encore

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
dfw.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ###### petit sammairy de variables

# %%
dfw.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ###### sa genere la correlation entre toutes les variables

# %% [markdown]
# ### Correlation Matrix

# %%
corr = dfw.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### pour les correlation qui depasse 0.5 on a entre density et residual sugar ,total sulfur dioxide et free sulfur dioxide ,density ettotal sulfur dioxide en fin une correlation negative entre alcool et density

# %% [markdown]
# ### Visualisation

# %%
sns.violinplot(y = "fixed acidity", data = dfw)
# Out:
# <AxesSubplot:ylabel='fixed acidity'>

# %% [markdown]
# * Distribution du variable fixed acidity (acidité fixer) en plus on a :
#     * max = 14.20
#     * min= 3.80
#     * moyenne = 8.319637

# %%
sns.violinplot(y = "volatile acidity", data = dfw)
# Out:
# <AxesSubplot:ylabel='volatile acidity'>

# %% [markdown]
# * Distribution du variable volatile acidity(acidité volatile):
#     * max = 1.10
#     * min = 0.08
#     * moyenne = 0.278241

# %%
sns.violinplot(y = "citric acid", data = dfw)
# Out:
# <AxesSubplot:ylabel='citric acid'>

# %% [markdown]
# *  La distribution du variable citric acid(acide citrique):
#     * min = 0
#     * max  = 1.66
#     * moyenne = 0.334192

# %%
sns.violinplot(y = "residual sugar", data = dfw)
# Out:
# <AxesSubplot:ylabel='residual sugar'>

# %% [markdown]
# * La distribution du variable  residual sugar(sucre résiduel):
#     * min = 0.60
#     * max =  65.80
#     * moyenne = 6.391415

# %%
sns.violinplot(y = "chlorides", data = dfw)
# Out:
# <AxesSubplot:ylabel='chlorides'>

# %% [markdown]
# *  la distribution du variable chlorides(chlorures):
#     * max = 0.346
#     * min = 0.009
#     * moyenne = 0.045772

# %%
sns.violinplot(y = "free sulfur dioxide", data = dfw)
# Out:
# <AxesSubplot:ylabel='free sulfur dioxide'>

# %% [markdown]
# * La distribution du variable free sulfur dioxide (dioxyde de soufre libre):.
#     * max = 289
#     * min =2
#     * moyenne = 35.308085

# %%
sns.violinplot(y = "total sulfur dioxide", data = dfw)
# Out:
# <AxesSubplot:ylabel='total sulfur dioxide'>

# %% [markdown]
# * La distribution du variable total sulfur dioxide (dioxyde de soufre total):.
#     * max = 440
#     * min =9
#     * moyenne = 138.360657

# %%
sns.violinplot(y = "density", data = dfw)
# Out:
# <AxesSubplot:ylabel='density'>

# %% [markdown]
# * La distribution du variable density (g/cm3)la densité en plus :
#     * max = 1.038
#     * min =0.98
#     * moyenne = 0.994027

# %%
sns.violinplot(y = "pH", data = dfw)
# Out:
# <AxesSubplot:ylabel='pH'>

# %% [markdown]
# * La distribution du variable pH on a :
#
#     * max = 3.82
#     * min =2.72
#     * moyenne =3.188267

# %%
sns.violinplot(y = "sulphates", data = dfw)
# Out:
# <AxesSubplot:ylabel='sulphates'>

# %% [markdown]
# * La distribution du variable sulphates :
#     * max = 1.08
#     * min =0.22
#     * moyenne =0.489847

# %%
sns.violinplot(y = "alcohol", data = dfw)
# Out:
# <AxesSubplot:ylabel='alcohol'>

# %% [markdown]
# *  La distribution du variable alcohol
#     * max = 14.2
#     * min = 8
#     * moyenne =10.514267

# %%
sns.violinplot(y = "quality", data = dfw)
# Out:
# <AxesSubplot:ylabel='quality'>

# %% [markdown]
# * La distribution du variable quality qualité (score entre 0 et 10)
#      * max = 9
#      * min = 3
#      * moyenne = 5.877909

# %% [markdown]
# ###### Avec violinplot on visualise les densites de chaque variables et on remarque distribution de leurs  valeurs

# %%
for colonne in dfw.select_dtypes('float'):
    plt.figure(figsize = (10,8))
    sns.distplot(dfr[colonne])
    plt.show()

# %%
plt.figure(figsize = (10,8))
sns.distplot(dfw['quality'])
plt.show()

# %% [markdown]
# ###### On a  les histogramme de distribution pour chaque variables

# %% [markdown]
# ##  Preparation des donnees

# %%
dfr['color']=0 #0 pour couleur rouge 
dfr.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  color
# 0      9.4        5      0
# 1      9.8        5      0
# ...

# %%
dfw['color']=1 #1 pour couleur blanc 
dfw.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6      1
# 1      9.5        6      1
# ...

# %% [markdown]
# ###### On fait une concatination de 2 dataset wine red et wine white

# %%
import pandas as pd

# %%
dft=pd.concat([dfr,dfw])

# %%
dft.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  color
# 0      9.4        5      0
# 1      9.8        5      0
# ...

# %%
dft.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# ...

# %%
dft.shape
# Out:
# (6497, 13)

# %%
dft.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
dft_PATH = os.path.join("../", "datasets", "dft.csv")
helpers.save_csv(dft, dft_PATH)

# %% [markdown]
# ### Correlation Matrix

# %%
corr = dft.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,
annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### pour les correlation qui depasse 0.5 on a entre density et residual sugar ,total sulfur dioxide et residual sugar,total sulfur dioxide et free sulfur dioxide , en fin une correlation negative entre alcool et density

# %% [markdown]
#    * total sulfur dioxide et residual sugar= 0.5
#    *  density et residual sugar=0.55
#    * total sulfur dioxide et free sulfur dioxide= 0.72
#    *  alcool et density = -0.69

# %% [markdown]
# ###### * Comme density est corre avec alcohol et residual sugar  on ne  peut pas  le supprimer sinon on va perdre beaucoup de informations

# %% [markdown]
# ### Visualisation pour dataset_Final

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(dft,figsize=(15,15))
plt.show()

# %% [markdown]
# ###### ici on a  scatter_matrix pour visualiser les relation entre les variables

# %%
sns.stripplot(y = "fixed acidity", data = dft)
# Out:
# <AxesSubplot:ylabel='fixed acidity'>

# %% [markdown]
# ###### On a ici dispersion de valeurs fixed acidity

# %% [markdown]
#    * max = 15.9
#    * min= 3.80
#    * moyenne =7.215307

# %%
sns.stripplot(y = "volatile acidity", data = dft)
# Out:
# <AxesSubplot:ylabel='volatile acidity'>

# %% [markdown]
# ###### dispersion de valeurs de volatile acidity

# %% [markdown]
#    * max = 1.58
#    * min= 0.08
#    * moyenne =0.3396

# %%
sns.stripplot(y = "citric acid", data = dft)
# Out:
# <AxesSubplot:ylabel='citric acid'>

# %% [markdown]
# ###### dispersion de valeurs citric acid

# %% [markdown]
#    * max = 1.66
#    * min= 0
#    * moyenne =0.3186

# %%
sns.stripplot(y = "residual sugar", data = dft)
# Out:
# <AxesSubplot:ylabel='residual sugar'>

# %% [markdown]
# ###### dispersion de valeurs residual sugar  on remarque qu'il ya une valeur aberante

# %% [markdown]
#    * max = 65.8
#    * min= 0.6
#    * moyenne =5.4432

# %%
sns.stripplot(y = "chlorides", data = dft)
# Out:
# <AxesSubplot:ylabel='chlorides'>

# %% [markdown]
# ###### dispersion de valeurs chlorides

# %% [markdown]
#    * max = 0.611
#    * min= 0.009
#    * moyenne =0.056

# %%
sns.stripplot(y = "free sulfur dioxide", data = dft)
# Out:
# <AxesSubplot:ylabel='free sulfur dioxide'>

# %% [markdown]
# ###### dispersion de valeurs free sulfur dioxide on remarque qu'il ya une valeurs loin des autres

# %% [markdown]
#    * max = 289
#    * min= 1
#    * moyenne =30.5253

# %%
sns.stripplot(y = "total sulfur dioxide", data = dft)
# Out:
# <AxesSubplot:ylabel='total sulfur dioxide'>

# %% [markdown]
# ###### dispersion de valeurs total sulfur dioxide

# %% [markdown]
#    * max = 440
#    * min= 6
#    * moyenne =115.7445

# %%
sns.stripplot(y = "density", data = dft)
# Out:
# <AxesSubplot:ylabel='density'>

# %% [markdown]
# ###### dispersion de valeurs density on remarque qu'il ya une valeurs loin des autres

# %% [markdown]
#    * max = 1.0389
#    * min= 0.9871
#    * moyenne =0.9946

# %%
sns.stripplot(y = "pH", data = dft)
# Out:
# <AxesSubplot:ylabel='pH'>

# %% [markdown]
# ###### dispersion de valeurs pH

# %% [markdown]
#    * max = 4.010
#    * min= 2.72
#    * moyenne =3.2185

# %%
sns.stripplot(y = "sulphates", data = dft)
# Out:
# <AxesSubplot:ylabel='sulphates'>

# %% [markdown]
# ###### dispersion de valeurs sulphates

# %% [markdown]
#    * max = 2
#    * min= 0.22
#    * moyenne =0.5312

# %%
sns.stripplot(y = "alcohol", data = dft)
# Out:
# <AxesSubplot:ylabel='alcohol'>

# %% [markdown]
# ###### dispersion de valeurs alcohol

# %% [markdown]
#    * max = 14.9
#    * min= 8
#    * moyenne =10.4918

# %%
sns.stripplot(y = "quality", data = dft)
# Out:
# <AxesSubplot:ylabel='quality'>

# %% [markdown]
# ###### dispersion de valeurs quality

# %% [markdown]
#    * max = 9
#    * min= 3
#    * moyenne =5.8183

# %%
with sns.axes_style('white'):
    sns.jointplot("density", "alcohol", data=dft, kind='reg')

# %% [markdown]
# ###### on remarque la regression lineaire simple  entre alcohol et density

# %%
with sns.axes_style('white'):
    sns.jointplot("density", "residual sugar", data=dft, kind='reg')

# %% [markdown]
# ###### on visualise la regression lineaire simple entre density et total residual sugar

# %%
with sns.axes_style('white'):
    sns.jointplot("density", "total sulfur dioxide", data=dft, kind='reg')

# %% [markdown]
# ###### la regression lineaire simple entre density et total sulfur dioxide

# %%
with sns.axes_style('white'):
    sns.jointplot("total sulfur dioxide", "free sulfur dioxide", data=dft, kind='reg')

# %% [markdown]
# ###### la regression lineaire simple entre  free sulfur dioxide et total sulfur dioxide

# %%
sns.boxplot(y="alcohol",x="color",data=dft)
# Out:
# <AxesSubplot:xlabel='color', ylabel='alcohol'>

# %% [markdown]
# ###### boxplot entre color et variable alcohol il y a une difference entre  min ,max et mean pour color =0 et celle pour color=1 et on remarque de valeurs aberants pour color = 0

# %%
sns.boxplot(y="total sulfur dioxide",x="color",data=dft)
# Out:
# <AxesSubplot:xlabel='color', ylabel='total sulfur dioxide'>

# %% [markdown]
# ###### boxplot entre color et total sulfur dioxide on voit  la diffence entre min ,max et  pour color=0 et celle pour  color=1on remarque de valeurs aberants dans 2 cotes

# %%
dft = dft.drop('free sulfur dioxide', axis=1)

# %% [markdown]
# ###### on peut supprimer free sulfur dioxide comme il est corre avec total sulfur dioxide

# %%
sns.countplot(x="color",data=dft)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
def snake_case_col(name):
    """
    Snakecaseify a string
    :param name: str
        column name
    :return:
    """
    return name.strip().lower().replace(" ", "_")

# %%
dft=dft.rename(columns=snake_case_col)
dft.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    total_sulfur_dioxide  density    ph  sulphates  alcohol  quality  color
# 0                  34.0   0.9978  3.51       0.56      9.4        5      0
# 1                  67.0   0.9968  3.20       0.68      9.8        5      0
# 2                  54.0   0.9970  3.26       0.65      9.8        5      0
# 3                  60.0   0.9980  3.16       0.58      9.8        6      0
# 4                  34.0   0.9978  3.51       0.56      9.4        5      0

# %%
# Normalize feature variable
#from sklearn.preprocessing import StandardScaler
#X_features = X
#X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
strata = dft.color
dft_train, dft_test = train_test_split(dft, test_size=0.2, random_state=28, stratify=strata)

# %%
dft_train['color'].value_counts(normalize=True) * 100
# Out:
# 1    75.389648
# 0    24.610352
# Name: color, dtype: float64

# %%
dft_test['color'].value_counts(normalize=True) * 100
# Out:
# 1    75.384615
# 0    24.615385
# Name: color, dtype: float64

# %%
TRAIN_PATH = os.path.join("../", "datasets", "dft_train.csv")
TEST_PATH = os.path.join("../", "datasets", "dft_test.csv")
helpers.save_csv(dft_train, TRAIN_PATH)
helpers.save_csv(dft_test, TEST_PATH)
